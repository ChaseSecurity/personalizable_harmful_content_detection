# %% [markdown]
# # Import libraries

# %%
import pandas as pd
# from retriv import SparseRetriever, DenseRetriever
from vllm import LLM
import os
from ..ICLLeaner import InContextLearner
from ..taskDescription import system_descs
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = "1,2"

# %% [markdown]
# # Initialize the model

# %%
    
max_context_length = 32 * 1024
modelID = 'Qwen2.5-7B-Instruct' # 'Meta-Llama-3.1-8B-Instruct' 'Mistral-7B-Instruct-v0.3'
model = LLM(model='/data/rfzhang/harmfultext/model/' + modelID,tensor_parallel_size=2, gpu_memory_utilization=0.8, max_model_len = max_context_length)
# Out:
# INFO 10-17 14:42:49 [utils.py:328] non-default args: {'max_model_len': 32768, 'tensor_parallel_size': 2, 'gpu_memory_utilization': 0.8, 'disable_log_stats': True, 'model': '/data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct'}
# INFO 10-17 14:42:49 [__init__.py:742] Resolved architecture: Qwen2ForCausalLM
# INFO 10-17 14:42:49 [__init__.py:1815] Using max model len 32768
# INFO 10-17 14:42:49 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:50 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:50 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='/data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct', speculative_config=None, tokenizer='/data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=451980) WARNING 10-17 14:42:50 [multiproc_worker_utils.py:273] Reducing Torch parallelism from 24 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:50 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1], buffer_handle=(2, 16777216, 10, 'psm_86fd01ea'), local_subscribe_addr='ipc:///tmp/d0ee15e3-f10b-4153-b694-4274b1376468', remote_subscribe_addr=None, remote_addr_ipv6=False)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) INFO 10-17 14:42:52 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_8659ee95'), local_subscribe_addr='ipc:///tmp/9906ce45-57db-4e10-b80b-79d9f017c8ae', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 10-17 14:42:52 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_fb473fea'), local_subscribe_addr='ipc:///tmp/1d1f89d6-a723-45ee-b534-a09ffadce621', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [__init__.py:1433] Found nccl from library libnccl.so.2
# INFO 10-17 14:42:53 [__init__.py:1433] Found nccl from library libnccl.so.2
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [pynccl.py:70] vLLM is using nccl==2.27.3
# INFO 10-17 14:42:53 [pynccl.py:70] vLLM is using nccl==2.27.3
# [W1017 14:42:53.993725845 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [W1017 14:42:53.002946743 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [custom_all_reduce.py:35] Skipping P2P check and trusting the driver's P2P report.
# INFO 10-17 14:42:53 [custom_all_reduce.py:35] Skipping P2P check and trusting the driver's P2P report.
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) WARNING 10-17 14:42:53 [custom_all_reduce.py:154] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 10-17 14:42:53 [custom_all_reduce.py:154] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_f0274091'), local_subscribe_addr='ipc:///tmp/b92936e1-c977-4bdc-a167-3bd89e1071f3', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [parallel_state.py:1165] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=451980) INFO 10-17 14:42:53 [parallel_state.py:1165] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) WARNING 10-17 14:42:53 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# WARNING 10-17 14:42:53 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1[Gloo] Rank
# 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:42:54 [gpu_model_runner.py:2338] Starting to load model /data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct...
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:42:54 [gpu_model_runner.py:2338] Starting to load model /data/rfzhang/harmfultext/model/Qwen2.5-7B-Instruct...
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:42:54 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:42:54 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:42:54 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:42:54 [cuda.py:362] Using Flash Attention backend on V1 engine.
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002)
# Processed prompts:  77%|███████▋  | 768/1000 [00:20<00:00, 274.60it/s, est. speed input: 60081.33 toks/s, output: 849.54 toks/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:13<00:39, 13.10s/it]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:14<00:12,  6.13s/it]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:15<00:03,  3.97s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:16<00:00,  4.24s/it]
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002)
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:11 [default_loader.py:268] Loading weights took 17.07 seconds
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:12 [default_loader.py:268] Loading weights took 17.53 seconds
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:12 [gpu_model_runner.py:2392] Model loading took 7.1214 GiB and 17.260166 seconds
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:13 [gpu_model_runner.py:2392] Model loading took 7.1214 GiB and 17.712566 seconds
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) (Worker_TP0 pid=452002) INFO 10-17 14:43:19 [backends.py:539] Using cache directory: /home/rfzhang/.cache/vllm/torch_compile_cache/4c945fc089/rank_1_0/backbone for vLLM's torch.compile
# INFO 10-17 14:43:19 [backends.py:539] Using cache directory: /home/rfzhang/.cache/vllm/torch_compile_cache/4c945fc089/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) (Worker_TP0 pid=452002) INFO 10-17 14:43:19 [backends.py:550] Dynamo bytecode transform time: 5.61 s
# INFO 10-17 14:43:19 [backends.py:550] Dynamo bytecode transform time: 5.61 s
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:21 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.844 s
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:21 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.857 s
# (EngineCore_DP0 pid=451980) (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) (Worker_TP0 pid=452002) INFO 10-17 14:43:22 [monitor.py:34] torch.compile takes 5.61 s in total
# INFO 10-17 14:43:22 [monitor.py:34] torch.compile takes 5.61 s in total
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:24 [gpu_worker.py:298] Available KV cache memory: 10.16 GiB
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:24 [gpu_worker.py:298] Available KV cache memory: 10.16 GiB
# (EngineCore_DP0 pid=451980) INFO 10-17 14:43:25 [kv_cache_utils.py:864] GPU KV cache size: 380,560 tokens
# (EngineCore_DP0 pid=451980) INFO 10-17 14:43:25 [kv_cache_utils.py:868] Maximum concurrency for 32,768 tokens per request: 11.61x
# (EngineCore_DP0 pid=451980) INFO 10-17 14:43:25 [kv_cache_utils.py:864] GPU KV cache size: 380,560 tokens
# (EngineCore_DP0 pid=451980) INFO 10-17 14:43:25 [kv_cache_utils.py:868] Maximum concurrency for 32,768 tokens per request: 11.61x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:06<00:00, 10.96it/s], output: 849.54 toks/s]
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:32 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 0.85 GiB
# (EngineCore_DP0 pid=451980) (Worker_TP0 pid=452002) INFO 10-17 14:43:32 [gpu_worker.py:391] Free memory on device (21.26/23.59 GiB) on startup. Desired GPU memory utilization is (0.8, 18.87 GiB). Actual usage is 7.12 GiB for weight, 1.45 GiB for peak activation, 0.14 GiB for non-torch memory, and 0.85 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9840107520` to fit into requested memory, or `--kv-cache-memory=12400992256` to fully utilize gpu memory. Current kv cache memory in use is 10911752192 bytes.
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:32 [gpu_model_runner.py:3118] Graph capturing finished in 7 secs, took 0.85 GiB
# (EngineCore_DP0 pid=451980) (Worker_TP1 pid=452004) INFO 10-17 14:43:32 [gpu_worker.py:391] Free memory on device (23.29/23.59 GiB) on startup. Desired GPU memory utilization is (0.8, 18.87 GiB). Actual usage is 7.12 GiB for weight, 1.45 GiB for peak activation, 0.14 GiB for non-torch memory, and 0.85 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=9840107520` to fit into requested memory, or `--kv-cache-memory=14585503744` to fully utilize gpu memory. Current kv cache memory in use is 10911752192 bytes.
# (EngineCore_DP0 pid=451980) INFO 10-17 14:43:32 [core.py:218] init engine (profile, create kv cache, warmup model) took 19.39 seconds
# INFO 10-17 14:43:33 [llm.py:295] Supported_tasks: ['generate']
# INFO 10-17 14:43:33 [__init__.py:36] No IOProcessor plugins requested by the model
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:50 [multiproc_executor.py:149] Worker proc VllmWorker-0 died unexpectedly, shutting down executor.
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720] EngineCore encountered a fatal error.
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720] Traceback (most recent call last):
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 711, in run_engine_core
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]     engine_core.run_busy_loop()
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 736, in run_busy_loop
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]     self._process_input_queue()
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 750, in _process_input_queue
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]     self._handle_client_request(*req)
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 796, in _handle_client_request
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720]     raise RuntimeError("Executor failed.")
# (EngineCore_DP0 pid=451980) ERROR 10-17 16:06:51 [core.py:720] RuntimeError: Executor failed.
# (EngineCore_DP0 pid=451980) Process EngineCore_DP0:
# (EngineCore_DP0 pid=451980) Traceback (most recent call last):
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
# (EngineCore_DP0 pid=451980)     self.run()
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/multiprocessing/process.py", line 108, in run
# (EngineCore_DP0 pid=451980)     self._target(*self._args, **self._kwargs)
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 722, in run_engine_core
# (EngineCore_DP0 pid=451980)     raise e
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 711, in run_engine_core
# (EngineCore_DP0 pid=451980)     engine_core.run_busy_loop()
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 736, in run_busy_loop
# (EngineCore_DP0 pid=451980)     self._process_input_queue()
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 750, in _process_input_queue
# (EngineCore_DP0 pid=451980)     self._handle_client_request(*req)
# (EngineCore_DP0 pid=451980)   File "/data2/rfzhang/anaconda3/envs/vllm0102/lib/python3.12/site-packages/vllm/v1/engine/core.py", line 796, in _handle_client_request
# (EngineCore_DP0 pid=451980)     raise RuntimeError("Executor failed.")
# (EngineCore_DP0 pid=451980) RuntimeError: Executor failed.

# %% [markdown]
# # single-task binary

# %% [markdown]
# ## Spam

# %%
task_type = 'specific_binary'
category = 'spam'
new_shots = 0
reasoning = False
random_seed = 42
instruction_type = 'level1-chats'
retrieval = 'random'
shots_list = [0]
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'sscd'
json_results = "./results/results.json"
label_names = ['ham', 'spam']

df = pd.read_csv('../datasets/spam/sscd.csv', encoding='utf-8', sep='\t')
df.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
df['original_label'] = df['label']
print(df['label'].value_counts())
# get test set
test_df = df.sample(frac=0.2, random_state=42)  # fix random_state for reproducibility
# test_df.to_csv('../datasets/spam/sscd_test.csv', index=False, encoding='utf-8', sep='\t')
print(test_df['label'].value_counts())
# get remaining data
df_remaining = df.drop(test_df.index)
df_remaining.reset_index(drop=True, inplace=True)
# df_remaining.to_csv('../datasets/spam/sscd_train.csv', index=False, encoding='utf-8', sep='\t')
print(df_remaining['label'].value_counts())
# Out:
# label
# ham     4827
# spam     747
# Name: count, dtype: int64
# label
# ham     954
# spam    161
# Name: count, dtype: int64
# label
# ham     3873
# spam     586
# Name: count, dtype: int64

# %% [markdown]
# ## Toxic

# %%
task_type = 'specific_binary'
category = 'toxic'
new_shots = 0
reasoning = False
random_seed = 42
instruction_type = 'level1-chats'
retrieval = 'random'
shots_list = [0]
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'textdetox'
json_results = "./results/results.json"
label_names = ['benign', 'toxic']

df = pd.read_parquet('../datasets/toxic/multilingual_toxicity_dataset/en-00000-of-00001.parquet')
df.rename(columns={'toxic': 'label'}, inplace=True)
df['label'] = df['label'].map({0: 'benign', 1: 'toxic'})
df['original_label'] = df['label']
print(df['label'].value_counts())
# get test set
test_df = df.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
# test_df.to_csv('../datasets/toxic/multilingual_toxicity_dataset/en_test.csv', index=False, encoding='utf-8', sep='\t')
print(test_df['label'].value_counts())
# get remaining data
df_remaining = df.drop(test_df.index)
df_remaining.reset_index(drop=True, inplace=True)
# df_remaining.to_csv('../datasets/toxic/multilingual_toxicity_dataset/en_train.csv', index=False, encoding='utf-8', sep='\t')
print(df_remaining['label'].value_counts())
# Out:
# label
# benign    2500
# toxic     2500
# Name: count, dtype: int64
# label
# benign    500
# toxic     500
# Name: count, dtype: int64
# label
# benign    2000
# toxic     2000
# Name: count, dtype: int64

# %% [markdown]
# ## Negative emotion

# %%
task_type = 'specific_binary'
category = 'emotion'
new_shots = 0
reasoning = False
random_seed = 42
instruction_type = 'level1-chats'
retrieval = 'random'
shots_list = [0]
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'sst2'
json_results = "./results/results.json"
label_names = ['positive', 'negative']

# emotion

# get test set
test_df = pd.read_parquet('../datasets/emotion/data/validation-00000-of-00001.parquet')
test_df.rename(columns={'sentence': 'text'}, inplace=True)
test_df['label'] = test_df['label'].map({0: 'negative', 1: 'positive'})
test_df['original_label'] = test_df['label']
print(test_df['label'].value_counts())
# get training set
df_remaining = pd.read_parquet('../datasets/emotion/data/train-00000-of-00001.parquet')
df_remaining.rename(columns={'sentence': 'text'}, inplace=True)
df_remaining['label'] = df_remaining['label'].map({0: 'negative', 1: 'positive'})
df_remaining['original_label'] = df_remaining['label']
print(df_remaining['label'].value_counts())
# Out:
# label
# positive    444
# negative    428
# Name: count, dtype: int64
# label
# positive    37569
# negative    29780
# Name: count, dtype: int64

# %% [markdown]
# # multi-task

# %% [markdown]
# ## Binary classification

# %%
task_type = 'binary'
category = 'All'
new_shots = 0
reasoning = False
random_seed = 42
instruction_type = 'level1-chats'
retrieval = 'random'
shots_list = [0]
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'All'
json_results = "./results/results.json"
label_names = ['benign', 'harmful']
# spam
df1 = pd.read_csv('./datasets/spam/sscd.csv', encoding='utf-8', sep='\t')
df1.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
df1['original_label'] = df1['label']
df1['label'] = df1['label'].map({'ham': 'benign','spam': 'harmful'})
# get test set
sms_test_df = df1.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
sms_df_remaining = df1.drop(sms_test_df.index)
sms_df_remaining.reset_index(drop=True, inplace=True)

ham_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'ham']
spam_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'spam']
print(ham_df_remaining.shape)   
print(spam_df_remaining.shape)   

# toxic 
df2 = pd.read_parquet('./datasets/toxic/multilingual_toxicity_dataset/en-00000-of-00001.parquet')
df2.rename(columns={'toxic': 'label'}, inplace=True)
df2['label'] = df2['label'].map({0: 'benign', 1: 'toxic'})
df2['original_label'] = df2['label']
df2['label'] = df2['label'].map({'benign': 'benign', 'toxic': 'harmful'})

# get test set
toxicity_test_df = df2.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
toxicity_df_remaining = df2.drop(toxicity_test_df.index)
toxicity_df_remaining.reset_index(drop=True, inplace=True)

non_toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'benign']
toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'toxic']
print(non_toxic_df_remaining.shape)   
print(toxic_df_remaining.shape)   
# emotion
df3 = pd.read_parquet('./datasets/emotion/data/train-00000-of-00001.parquet')
df3.rename(columns={'sentence': 'text'}, inplace=True)
df3['label'] = df3['label'].map({0: 'negative', 1: 'positive'})
df3['original_label'] = df3['label']
df3['label'] = df3['label'].map({'negative': 'harmful', 'positive': 'benign'})

# get test set
emotion_test_df = pd.read_parquet('./datasets/emotion/data/validation-00000-of-00001.parquet')
emotion_test_df.rename(columns={'sentence': 'text'}, inplace=True)
emotion_test_df['label'] = emotion_test_df['label'].map({0: 'negative', 1: 'positive'})
emotion_test_df['original_label'] = emotion_test_df['label']
emotion_test_df['label'] = emotion_test_df['label'].map({'negative': 'harmful', 'positive': 'benign'})

emotion_df_remaining = df3

positive_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'positive']
negative_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'negative']
print(positive_df_remaining.shape)   
print(negative_df_remaining.shape)   
# merge datasets

test_df = pd.concat([sms_test_df, toxicity_test_df, emotion_test_df], ignore_index=True)
df_remaining = pd.concat([sms_df_remaining, toxicity_df_remaining, emotion_df_remaining], ignore_index=True)
print(df_remaining.shape)   
# test_df = test_df.head(10)
# test_df.to_csv('./demos.csv', index=False)
# Out:
# (3873, 3)
# (586, 3)
# (2000, 3)
# (2000, 3)
# (37569, 4)
# (29780, 4)
# (75808, 4)

# %% [markdown]
# ## multi-class-3-1 classification

# %%
# nulti-class classification task
import pandas as pd
# set parameters
task_type = 'multi-class-3-1'
category = 'All'
random_seed = 42
instruction_type = 'level1-chats'
retrieval = 'random'
shots_list = [6]
new_shots = 0
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'All'
json_results = "./results/results_all.json"
label_names = ['benign', 'spam', 'toxic', 'negative']
# spam
df1 = pd.read_csv('./datasets/spam/sscd.csv', encoding='utf-8', sep='\t')
df1.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
df1['original_label'] = df1['label']
df1['label'] = df1['label'].replace({'ham': 'benign'})
# get test set
sms_test_df = df1.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
sms_df_remaining = df1.drop(sms_test_df.index)
sms_df_remaining.reset_index(drop=True, inplace=True)

ham_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'ham']
spam_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'spam']
print(ham_df_remaining.shape)   
print(spam_df_remaining.shape)   

# toxic 
df2 = pd.read_parquet('./datasets/toxic/multilingual_toxicity_dataset/en-00000-of-00001.parquet')
df2.rename(columns={'toxic': 'label'}, inplace=True)
df2['label'] = df2['label'].map({0: 'benign', 1: 'toxic'})
df2['original_label'] = df2['label']
df2['label'] = df2['label'].replace({'benign': 'benign'})

# get test set
toxicity_test_df = df2.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
toxicity_df_remaining = df2.drop(toxicity_test_df.index)
toxicity_df_remaining.reset_index(drop=True, inplace=True)

non_toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'benign']
toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'toxic']
print(non_toxic_df_remaining.shape)   
print(toxic_df_remaining.shape)   
# emotion
df3 = pd.read_parquet('./datasets/emotion/data/train-00000-of-00001.parquet')
df3.rename(columns={'sentence': 'text'}, inplace=True)
df3['label'] = df3['label'].map({0: 'negative', 1: 'positive'})
df3['original_label'] = df3['label']
df3['label'] = df3['label'].replace({'positive': 'benign'})

# get test set
emotion_test_df = pd.read_parquet('./datasets/emotion/data/validation-00000-of-00001.parquet')
emotion_test_df.rename(columns={'sentence': 'text'}, inplace=True)
emotion_test_df['label'] = emotion_test_df['label'].map({0: 'negative', 1: 'positive'})
emotion_test_df['original_label'] = emotion_test_df['label']
emotion_test_df['label'] = emotion_test_df['label'].replace({ 'positive': 'benign'})

emotion_df_remaining = df3

positive_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'positive']
negative_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'negative']

print(positive_df_remaining.shape)   
print(negative_df_remaining.shape)   
# merge datasets

test_df = pd.concat([sms_test_df, toxicity_test_df, emotion_test_df], ignore_index=True)
# display(test_df.head(20))
# test_df = test_df.sample(frac=1).reset_index(drop=True)
# display(test_df.head(20))
df_remaining = pd.concat([sms_df_remaining, toxicity_df_remaining, emotion_df_remaining], ignore_index=True)
print(df_remaining.shape)
# Out:
# (3873, 3)
# (586, 3)
# (2000, 3)
# (2000, 3)
# (37569, 4)
# (29780, 4)
# (75808, 4)

# %% [markdown]
# ## multi-class-3-3 classification

# %%
# nulti-class classification task

import pandas as pd
# set parameters
task_type = 'multi-class-3-3'
category = 'All'
random_seed = 42
instruction_type = 'level1'
# retrieval = 'Fine-grained balanced semantic'
retrieval = 'random'
shots_list = [48, 96, 192]
harmful = 1
benign = 1
harmful_ratio = harmful/(harmful+benign) # ratio of harmful text samples
dataset = 'All-logits'
json_results = "./results/results_all.json"
label_names = ['benign', 'toxic', 'ham', 'spam', 'positive', 'negative']
# spam
df1 = pd.read_csv('../datasets/spam/sscd.csv', encoding='utf-8', sep='\t')
df1.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
df1['original_label'] = df1['label']
# df1['label'] = df1['label'].replace({'ham': 'benign', 'spam': 'harmful'})
# get test set
sms_test_df = df1.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
sms_df_remaining = df1.drop(sms_test_df.index)
sms_df_remaining.reset_index(drop=True, inplace=True)

ham_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'ham']
spam_df_remaining = sms_df_remaining[sms_df_remaining['original_label'] == 'spam']
print(ham_df_remaining.shape)   
print(spam_df_remaining.shape)   

# toxic 
df2 = pd.read_parquet('../datasets/toxic/multilingual_toxicity_dataset/en-00000-of-00001.parquet')
df2.rename(columns={'toxic': 'label'}, inplace=True)
df2['label'] = df2['label'].map({0: 'benign', 1: 'toxic'})
df2['original_label'] = df2['label']
# df2['label'] = df2['label'].replace({'benign': 'benign', 'toxic': 'harmful'})

# get test set
toxicity_test_df = df2.sample(frac=0.2, random_state=42)  # random_state 用于确保结果可重复
toxicity_df_remaining = df2.drop(toxicity_test_df.index)
toxicity_df_remaining.reset_index(drop=True, inplace=True)

non_toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'benign']
toxic_df_remaining = toxicity_df_remaining[toxicity_df_remaining['original_label'] == 'toxic']
print(non_toxic_df_remaining.shape)   
print(toxic_df_remaining.shape)   
# emotion
df3 = pd.read_parquet('../datasets/emotion/data/train-00000-of-00001.parquet')
df3.rename(columns={'sentence': 'text'}, inplace=True)
df3['label'] = df3['label'].map({0: 'negative', 1: 'positive'})
df3['original_label'] = df3['label']
# df3['label'] = df3['label'].replace({'positive': 'benign', 'negative': 'harmful'})

# get test set
emotion_test_df = pd.read_parquet('../datasets/emotion/data/validation-00000-of-00001.parquet')
emotion_test_df.rename(columns={'sentence': 'text'}, inplace=True)
emotion_test_df['label'] = emotion_test_df['label'].map({0: 'negative', 1: 'positive'})
emotion_test_df['original_label'] = emotion_test_df['label']
# emotion_test_df['label'] = emotion_test_df['label'].replace({ 'positive': 'benign', 'negative': 'harmful'})

emotion_df_remaining = df3

positive_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'positive']
negative_df_remaining = emotion_df_remaining[emotion_df_remaining['original_label'] == 'negative']

print(positive_df_remaining.shape)   
print(negative_df_remaining.shape)   
# merge datasets

test_df = pd.concat([sms_test_df, toxicity_test_df, emotion_test_df], ignore_index=True)
test_df = test_df.sample(frac=1).reset_index(drop=True)
df_remaining = pd.concat([sms_df_remaining, toxicity_df_remaining, emotion_df_remaining], ignore_index=True)
print(sms_test_df.shape)   
print(toxicity_test_df.shape)
print(emotion_test_df.shape)
# Out:
# (3873, 3)
# (586, 3)
# (2000, 3)
# (2000, 3)
# (37569, 4)
# (29780, 4)
# (1115, 3)
# (1000, 3)
# (872, 4)

# %% [markdown]
# # run experiment

# %%
results = {}
icl = InContextLearner(task_type=task_type, reasoning= reasoning, model_name='', train_df=None, test_df=test_df, model=model, context_length=max_context_length, index_name="")

for n_shots in shots_list:
    for i in [0, 1, 2]:
        random_state = random_seed + i
        
        print(f"n_shots: {n_shots}, random_state: {random_state}, retrieval: {retrieval}, instruction_type: {instruction_type}")
        
        if retrieval != 'random' and i != 0:
            continue
        if new_shots == 0:
            result_file_name = f"./results/confidence/{task_type}_{category}_{modelID.replace('.','-')}_d{dataset}_i{instruction_type}_r{random_state}_n{n_shots}_r{retrieval}_p{harmful}-{benign}_t{len(test_df)}"
        else:
            result_file_name = f"./results/confidence/{task_type}_{category}_{modelID.replace('.','-')}_d{dataset}_i{instruction_type}_r{random_state}_n{n_shots}+{new_shots}_r{retrieval}_p{harmful}-{benign}_t{len(test_df)}"
        if reasoning:
            result_file_name += '_reasoning'
        result_file_name += '.csv'
        print(f"result_file_name: {result_file_name}")
        # break
        # result_file_name = './datasets/100+500_predicted.csv'
        if os.path.exists(result_file_name):
            print("This task has been done: result_file_name")
            # continue
        
        if retrieval == 'random':
            if task_type == 'specific_binary':
                train_df = (df_remaining.groupby("label", group_keys=False).apply(lambda x: x.sample(min(len(x), int(n_shots/2)), random_state=42))).reset_index(drop=True)
            else:
                train_df = pd.concat([ham_df_remaining.sample(n=int(n_shots/6), random_state=random_state), 
                                    spam_df_remaining.sample(n=int(n_shots/6), random_state=random_state), 
                                    toxic_df_remaining.sample(n=int(n_shots/6), random_state=random_state),
                                    non_toxic_df_remaining.sample(n=int(n_shots/6), random_state=random_state),
                                    positive_df_remaining.sample(n=int(n_shots/6), random_state=random_state),
                                    negative_df_remaining.sample(n=int(n_shots/6), random_state=random_state),
                                    ], ignore_index=True)
        else:
            train_df = df_remaining
        
        print(train_df.groupby('original_label').size())
        
        index_name = f"{n_shots}-shot-{i}"
        icl.index_name = index_name
        icl.train_df = train_df
        if task_type == 'specific_binary':
            system_description = system_descs[task_type][category][instruction_type]
        else:
            system_description = system_descs[task_type][instruction_type]
        print(new_shots)
        prompts = icl.generate_prompts(system_description=system_description,n_shots=n_shots+new_shots, retrieval=retrieval)
        # break
        # print(model.get_tokenizer().decode(prompts[0]['prompt_token_ids']))
        # result_df = pd.read_csv(result_file_name)
        # break
        
        outputs = icl.predictGuided(prompts=prompts, label_names=label_names, reasoning=reasoning)
        reasons, predicted_label_list, predicted_labels_list = icl.process_outputs(outputs=outputs, label_names=label_names)        
        # break
        # write the predicted labels and confidences to file
        
            
        result_df = test_df
        result_df['predicted_labels'] = predicted_labels_list
        result_df['predicted_label'] = predicted_label_list
        result_df['reasons'] = reasons
        # result_df['original_outputs'] = outputs
        result_df.to_csv(result_file_name, index=False)
# Out:
# n_shots: 6, random_state: 42, retrieval: random, instruction_type: level1-chats
# result_file_name: ./results/confidence/multi-class-3-1_All_Qwen2-5-7B-Instruct_dAll_ilevel1-chats_r42_n6_rrandom_p1-1_t2987.csv
# original_label
# benign      1
# ham         1
# negative    1
# positive    1
# spam        1
# toxic       1
# dtype: int64
# 0
# {'benign': {'ham': 1898, 'spam': 1898, 'toxic': 1898, 'benign': 1898, 'positive': 1898, 'negative': 1898}, 'spam': {'ham': 161, 'spam': 161, 'toxic': 161, 'benign': 161, 'positive': 161, 'negative': 161}, 'toxic': {'ham': 500, 'spam': 500, 'toxic': 500, 'benign': 500, 'positive': 500, 'negative': 500}, 'negative': {'ham': 428, 'spam': 428, 'toxic': 428, 'benign': 428, 'positive': 428, 'negative': 428}}
# Adding requests: 100%|██████████| 2987/2987 [00:00<00:00, 4175.88it/s]
# Processed prompts: 100%|██████████| 2987/2987 [00:19<00:00, 152.85it/s, est. speed input: 63025.14 toks/s, output: 418.65 toks/s]
